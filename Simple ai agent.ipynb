# %%
pip install pydantic-ai==0.1.3 pydantic-ai-slim[tavily]==0.1.3 --upgrade --upgrade-strategy eager
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install rich==13.7.1 botocore==1.34.69
# Out:
# ...
#    ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/12.0 MB 3.3 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.6/12.0 MB 4.2 MB/s eta 0:00:03
#    ------- -------------------------------- 2.4/12.0 MB 4.2 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.1/12.0 MB 3.9 MB/s eta 0:00:03
#    ------------- -------------------------- 3.9/12.0 MB 3.9 MB/s eta 0:00:03
#    -------------- ------------------------- 4.5/12.0 MB 3.8 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.2/12.0 MB 3.8 MB/s eta 0:00:02
#    -------------------- ------------------- 6.3/12.0 MB 3.9 MB/s eta 0:00:02
#    ------------------------ --------------- 7.3/12.0 MB 4.0 MB/s eta 0:00:02
#    --------------------------- ------------ 8.1/12.0 MB 4.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.7/12.0 MB 3.9 MB/s eta 0:00:01
# ...

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import os
from pydantic_ai.agent import Agent
from pydantic_ai.common_tools.tavily import tavily_search_tool

# %%
os.environ["GROQ_API_KEY"] = "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"

# %%
TAVILY_API_KEY = "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"

# %%
agent = Agent(
    'groq:llama-3.1-8b-instant',
    tools = [tavily_search_tool(TAVILY_API_KEY)],
    system_prompt = 'Search Tavily for the given query and return the results.',
)

# %%
result = agent.run_sync('Tell me the top news in the GenAI world recently.')
print(result.output)
# Out:
# Based on the results, it appears that there have been recent developments in the field of GenAI, including its use in various industries such as government, finance, and marketing. For example, the California Department of Transportation is using GenAI technology to improve state services, while Progressive Insurance is testing the limits of AI-generated ads. Additionally, Google is considering exclusive deals with Android phone makers for its Gemini AI app. Overall, it seems that GenAI is being explored and implemented in various ways, with both positive and negative implications.
